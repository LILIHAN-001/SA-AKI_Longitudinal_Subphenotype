# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows = 300
pd.set_option('display.max_columns', None)# 列显示不全
import math
import datetime as dt
import itertools
import random
import scipy.stats as stats
import seaborn as sns

# %%
df_mimic = pd.read_csv("../01.mimic/mimic_drug_useage.csv")
df_mimic.columns = df_mimic.columns.str.lower()
df_mimic = df_mimic.T.drop_duplicates().T

df_aumc = pd.read_csv("../02.aumc/aumc_drug_useage.csv")
df_aumc.columns = df_aumc.columns.str.lower()
df_aumc = df_aumc.T.drop_duplicates().T

df_mimic_drug = df_mimic.columns.tolist()
df_aumc_drug = df_aumc.columns.tolist()

# %%
df_aumc_drug
# Out:
# ['drukzak',
#  'nacl 0,9% spuit',
#  'nacl 0,45%/glucose 2',
#  'magnesiumsulfaat',
#  'propofol',
#  'fentanyl',
#  'nacl 0',
#  'nadroparine',
#  'noradrenaline',
#  'kaliumchloride',
#  'paracetamol',
#  'furosemide',
#  'sdd drank',
#  'sdd pasta',
#  'gelofusine',
#  'midazolam',
#  'ceftriaxon',
#  'nutrison protein plus',
#  'thiamine',
#  'cernevit multivitaminen',
#  "gefiltreerde ery's",
#  'macrogol x',
#  'haloperidol',
#  'pantoprazol',
#  'kaliumchloride drank',
#  'hydrocortison',
#  'glucose',
#  'spoorelementen',
#  'hypromellose',
#  'macrogol',
#  'water 150ml',
#  'natrium-kalium-fosfaat',
#  'heparine',
#  'oxazepam',
#  'cefotaxim',
#  'xylometazoline  neusspray',
#  'medicijnlijn medicatie',
#  'ri-lac',
#  'actrapid',
#  'lorazepam',
#  'metoprolol',
#  'erythromycine',
#  'morfine',
#  'fosfaatklysma',
#  'carbasalaatcalcium',
#  'ventolin:atrovent 1:',
#  'calcium glubionaat',
#  'amiodaron onderhoudsdosis',
#  'rocuronium',
#  'dopamine',
#  'enoximon',
#  'ventolin:atrovent:mucomyst 1:1:',
#  'velosuline',
#  'nutrison standaard',
#  'amiodaron oplaaddosis',
#  'insuline aspart',
#  'nitroglycerine',
#  'clonidine',
#  'vancomycine',
#  'nutrison sterilized water',
#  'water 100ml',
#  'temazepam',
#  'fytomenadion',
#  'captopril',
#  'metronidazol',
#  'supradyn',
#  'x nader te bepalen',
#  'cefazoline',
#  'ascorbinezuur',
#  'fresh frozen plasma',
#  'glycerofosfaat',
#  'water 50ml',
#  'ciprofloxacine',
#  'acetazolamide',
#  'metoclopram',
#  'amlodipine',
#  'vitamine b complex',
#  'oculentum simplex oogzalf',
#  'dobutamine',
#  'etomidaat',
#  'glucose 5% spuit',
#  'vla 150ml',
#  'thrombocyten suspensie',
#  'fluticason  neusspray',
#  'albumine',
#  'thee 150ml',
#  'tranexaminezuur',
#  'water 200ml',
#  'amoxicilline/clavulaanzuur',
#  'simvastatine',
#  'lisinopril',
#  'magnesiumoxide',
#  'natrium bicarbonaat 8',
#  'nicardipine',
#  'digoxine',
#  'flucloxacilline',
#  'clopidogrel',
#  'grouphpd']

# %%
df_mimic_drug
# Out:
# ['nacl',
#  'solution',
#  'dextrose',
#  'magnesium sulfate',
#  'potassium chloride',
#  'propofol',
#  'vancomycin',
#  'furosemide',
#  'insulin',
#  'fentanyl',
#  'piggyback',
#  'heparin sodium',
#  'kcl',
#  'calcium gluconate',
#  'phenylephrine',
#  'acetaminophen-iv',
#  'packed red blood cells',
#  'norepinephrine',
#  'albumin',
#  'morphine sulfate',
#  'lr',
#  'midazolam',
#  'pantoprazole',
#  'metoprolol',
#  'famotidine',
#  'cefepime',
#  'piperacillin-tazobactam',
#  'cefazolin',
#  'hydromorphone',
#  'dexmedetomidine',
#  'lorazepam',
#  'sterile water',
#  'hydralazine',
#  'k phos',
#  'nitroglycerin',
#  'd5 1/2ns',
#  'metronidazole',
#  'fresh frozen plasma',
#  'vasopressin',
#  'amiodarone',
#  'ranitidine',
#  'ceftriaxone',
#  'na phos',
#  'platelets',
#  'haloperidol',
#  'ciprofloxacin iv',
#  'levofloxacin',
#  'azithromycin',
#  'thiamine',
#  'sodium bicarbonate',
#  'grouphpd']

# %%
# 由chatgpt提供
aumc_to_mimic_mapping = {
    'drukzak': None,
    'nacl 0,9% spuit': 'nacl',
    'nacl 0,45%/glucose 2': 'dextrose',
    'magnesiumsulfaat': 'magnesium sulfate',
    'propofol': 'propofol',
    'fentanyl': 'fentanyl',
    'nacl 0': 'nacl',
    'nadroparine': 'heparin sodium',
    'noradrenaline': 'norepinephrine',
    'kaliumchloride': 'potassium chloride',
    'paracetamol': 'acetaminophen-iv',
    'furosemide': 'furosemide',
    'sdd drank': None,
    'sdd pasta': None,
    'gelofusine': 'lr',
    'midazolam': 'midazolam',
    'ceftriaxon': 'ceftriaxone',
    'nutrison protein plus': None,
    'thiamine': 'thiamine',
    'cernevit multivitaminen': 'thiamine',
    "gefiltreerde ery's": 'packed red blood cells',
    'macrogol x': None,
    'haloperidol': 'haloperidol',
    'pantoprazol': 'pantoprazole',
    'kaliumchloride drank': 'potassium chloride',
    'hydrocortison': None,
    'glucose': 'dextrose',
    'spoorelementen': None,
    'hypromellose': None,
    'macrogol': None,
    'water 150ml': 'sterile water',
    'natrium-kalium-fosfaat': 'na phos',
    'heparine': 'heparin sodium',
    'oxazepam': 'lorazepam',
    'cefotaxim': 'cefepime',
    'xylometazoline  neusspray': None,
    'medicijnlijn medicatie': None,
    'ri-lac': None,
    'actrapid': None,
    'lorazepam': 'lorazepam',
    'metoprolol': 'metoprolol',
    'erythromycine': 'azithromycin',
    'morfine': 'morphine sulfate',
    'fosfaatklysma': 'sodium bicarbonate',
    'carbasalaatcalcium': 'aspirin',
    'ventolin:atrovent 1:': None,
    'calcium glubionaat': 'calcium gluconate',
    'amiodaron onderhoudsdosis': 'amiodarone',
    'rocuronium': None,
    'dopamine': 'dopamine',
    'enoximon': 'milrinone',
    'ventolin:atrovent:mucomyst 1:1:': None,
    'velosuline': 'insulin',
    'nutrison standaard': None,
    'amiodaron oplaaddosis': 'amiodarone',
    'insuline aspart': 'insulin',
    'nitroglycerine': 'nitroglycerin',
    'clonidine': None,
    'vancomycine': 'vancomycin',
    'nutrison sterilized water': None,
    'water 100ml': 'sterile water',
    'temazepam': 'temazepam',
    'fytomenadion': 'vitamin k',
    'captopril': None,
    'metronidazol': 'metronidazole',
    'supradyn': 'multivitamin',
    'x nader te bepalen': None,
    'cefazoline': 'cefazolin',
    'ascorbinezuur': None,
    'fresh frozen plasma': 'fresh frozen plasma',
    'glycerofosfaat': 'k phos',
    'water 50ml': 'sterile water',
    'ciprofloxacine': 'ciprofloxacin iv',
    'acetazolamide': 'acetazolamide',
    'metoclopram': 'metoclopramide',
    'amlodipine': None,
    'vitamine b complex': 'thiamine',
    'oculentum simplex oogzalf': None,
    'dobutamine': 'dobutamine',
    'etomidaat': 'etomidate',
    'glucose 5% spuit': 'dextrose',
    'vla 150ml': None,
    'thrombocyten suspensie': 'platelets',
    'fluticason  neusspray': None,
    'albumine': 'albumin 5%',
    'thee 150ml': None,
    'tranexaminezuur': 'tranexamic acid',
    'water 200ml': 'sterile water',
    'amoxicilline/clavulaanzuur': None,
    'simvastatine': None,
    'lisinopril': None,
    'magnesiumoxide': 'magnesium oxide',
    'natrium bicarbonaat 8': 'sodium bicarbonate',
    'nicardipine': None,
    'digoxine': None,
    'flucloxacilline': None,
    'clopidogrel': 'clopidogrel',
    'grouphpd': None
}

common_drugs = [aumc_drug for aumc_drug in aumc_to_mimic_mapping.keys() if aumc_to_mimic_mapping[aumc_drug] is not None]

# Print the common drugs and their mappings
# for aumc_drug in common_drugs:
#     mimic_drug = aumc_to_mimic_mapping[aumc_drug]
#     print(f'AUMC Drug: {aumc_drug} -> MIMIC Drug: {mimic_drug}')

# %%
# mapping，取相同的药物
df_aumc.columns = [aumc_to_mimic_mapping[col] if col in aumc_to_mimic_mapping and aumc_to_mimic_mapping[col] is not None else col for col in df_aumc.columns]
df_aumc_drug = df_aumc.columns.tolist()
comm_drug = list(set(df_mimic_drug).intersection(set(df_aumc_drug)))

# 去除重复列
df_aumc = df_aumc.apply(lambda col: col if col[0] >= col[1] else col, axis=0)
df_aumc = df_aumc.loc[:, ~df_aumc.columns.duplicated()]
df_aumc = df_aumc.reset_index(drop=True)

comm_drug
# Out:
# ['packed red blood cells',
#  'propofol',
#  'ciprofloxacin iv',
#  'morphine sulfate',
#  'lr',
#  'potassium chloride',
#  'fentanyl',
#  'ceftriaxone',
#  'amiodarone',
#  'metoprolol',
#  'heparin sodium',
#  'insulin',
#  'haloperidol',
#  'furosemide',
#  'calcium gluconate',
#  'cefepime',
#  'sterile water',
#  'nitroglycerin',
#  'acetaminophen-iv',
#  'fresh frozen plasma',
#  'nacl',
#  'platelets',
#  'metronidazole',
#  'norepinephrine',
#  'sodium bicarbonate',
#  'vancomycin',
#  'azithromycin',
#  'lorazepam',
#  'grouphpd',
#  'dextrose',
#  'midazolam',
#  'k phos',
#  'na phos',
#  'cefazolin',
#  'pantoprazole',
#  'thiamine',
#  'magnesium sulfate']

# %%
df_mimicT = df_mimic[comm_drug].T
df_mimicT.columns = ["mimic_0","mimic_1","mimic_2","mimic_3"]
df_aumcT = df_aumc[comm_drug].T
df_aumcT.columns =["aumc_0","aumc_1","aumc_2","aumc_3"]

merged_df = pd.merge(df_mimicT, df_aumcT, how='outer', left_index=True, right_index=True)
merged_df = merged_df.drop_duplicates()
merged_df = merged_df.sort_values(["mimic_0"],ascending=False)
merged_df = merged_df.reset_index()
merged_df= merged_df.rename(columns={"index":"drug"})
merged_df.head(1)
# Out:
#    drug    mimic_0    mimic_1    mimic_2    mimic_3     aumc_0     aumc_1  \
# 0  nacl  97.178018  97.996918  96.628478  98.888889  92.670637  94.148936
#
#       aumc_2     aumc_3
# 0  91.857143  94.063927

# %%
merged_df.to_csv("common_durg_utilization.csv",index=False)

# %%
styled_df = (merged_df.reset_index(drop=True)
 .style
 .bar(subset=['mimic_0','mimic_2', 'mimic_1',  'mimic_3'], color='#fdc086' )
 .bar(subset=['aumc_0','aumc_2',  'aumc_1', 'aumc_3'], color='#7fc97f' )
)
#styled_df.columns = ["overall","MIMIC_C1","MIMIC_C2","MIMIC_C3"]
styled_df
# Out:
# <style type="text/css">
# #T_7def1_row0_col1, #T_7def1_row0_col2, #T_7def1_row0_col3, #T_7def1_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 100.0%, transparent 100.0%);
# }
# #T_7def1_row0_col5, #T_7def1_row0_col6, #T_7def1_row0_col7, #T_7def1_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 100.0%, transparent 100.0%);
# }
# #T_7def1_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 79.7%, transparent 79.7%);
# }
# #T_7def1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 85.2%, transparent 85.2%);
# }
# #T_7def1_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 76.2%, transparent 76.2%);
# }
# #T_7def1_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 89.6%, transparent 89.6%);
# }
# #T_7def1_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 95.4%, transparent 95.4%);
# }
# #T_7def1_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 94.5%, transparent 94.5%);
# }
# #T_7def1_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 96.0%, transparent 96.0%);
# }
# #T_7def1_row1_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 93.7%, transparent 93.7%);
# }
# #T_7def1_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 75.5%, transparent 75.5%);
# }
# #T_7def1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 70.2%, transparent 70.2%);
# }
# #T_7def1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 78.7%, transparent 78.7%);
# }
# #T_7def1_row2_col4, #T_7def1_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 67.4%, transparent 67.4%);
# }
# #T_7def1_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 95.3%, transparent 95.3%);
# }
# #T_7def1_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 96.2%, transparent 96.2%);
# }
# #T_7def1_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 94.9%, transparent 94.9%);
# }
# #T_7def1_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 94.7%, transparent 94.7%);
# }
# #T_7def1_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 74.0%, transparent 74.0%);
# }
# #T_7def1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 70.3%, transparent 70.3%);
# }
# #T_7def1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 77.0%, transparent 77.0%);
# }
# #T_7def1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 62.1%, transparent 62.1%);
# }
# #T_7def1_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 81.9%, transparent 81.9%);
# }
# #T_7def1_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 85.7%, transparent 85.7%);
# }
# #T_7def1_row3_col7, #T_7def1_row16_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 81.1%, transparent 81.1%);
# }
# #T_7def1_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 76.7%, transparent 76.7%);
# }
# #T_7def1_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 71.7%, transparent 71.7%);
# }
# #T_7def1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 66.4%, transparent 66.4%);
# }
# #T_7def1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 74.9%, transparent 74.9%);
# }
# #T_7def1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 64.3%, transparent 64.3%);
# }
# #T_7def1_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 95.1%, transparent 95.1%);
# }
# #T_7def1_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 91.0%, transparent 91.0%);
# }
# #T_7def1_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 96.4%, transparent 96.4%);
# }
# #T_7def1_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 97.1%, transparent 97.1%);
# }
# #T_7def1_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 71.3%, transparent 71.3%);
# }
# #T_7def1_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 76.7%, transparent 76.7%);
# }
# #T_7def1_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 84.3%, transparent 84.3%);
# }
# #T_7def1_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 26.0%, transparent 26.0%);
# }
# #T_7def1_row5_col6, #T_7def1_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 36.2%, transparent 36.2%);
# }
# #T_7def1_row5_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 20.8%, transparent 20.8%);
# }
# #T_7def1_row5_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 32.0%, transparent 32.0%);
# }
# #T_7def1_row6_col1, #T_7def1_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 67.1%, transparent 67.1%);
# }
# #T_7def1_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 73.1%, transparent 73.1%);
# }
# #T_7def1_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 65.4%, transparent 65.4%);
# }
# #T_7def1_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 59.8%, transparent 59.8%);
# }
# #T_7def1_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 76.3%, transparent 76.3%);
# }
# #T_7def1_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 83.8%, transparent 83.8%);
# }
# #T_7def1_row6_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 74.3%, transparent 74.3%);
# }
# #T_7def1_row6_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 69.4%, transparent 69.4%);
# }
# #T_7def1_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 66.9%, transparent 66.9%);
# }
# #T_7def1_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 67.7%, transparent 67.7%);
# }
# #T_7def1_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 66.8%, transparent 66.8%);
# }
# #T_7def1_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 65.7%, transparent 65.7%);
# }
# #T_7def1_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 27.6%, transparent 27.6%);
# }
# #T_7def1_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 29.0%, transparent 29.0%);
# }
# #T_7def1_row7_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 27.8%, transparent 27.8%);
# }
# #T_7def1_row7_col8, #T_7def1_row14_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 22.3%, transparent 22.3%);
# }
# #T_7def1_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 60.7%, transparent 60.7%);
# }
# #T_7def1_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 61.9%, transparent 61.9%);
# }
# #T_7def1_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 58.7%, transparent 58.7%);
# }
# #T_7def1_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 73.6%, transparent 73.6%);
# }
# #T_7def1_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 90.9%, transparent 90.9%);
# }
# #T_7def1_row8_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 94.2%, transparent 94.2%);
# }
# #T_7def1_row8_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 88.4%, transparent 88.4%);
# }
# #T_7def1_row8_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 98.1%, transparent 98.1%);
# }
# #T_7def1_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 58.5%, transparent 58.5%);
# }
# #T_7def1_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 59.0%, transparent 59.0%);
# }
# #T_7def1_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 58.4%, transparent 58.4%);
# }
# #T_7def1_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #fdc086 57.6%, transparent 57.6%);
# }
# #T_7def1_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #7fc97f 85.4%, transparent 85.4%);
# }
# #T_7def1_row9_col6 {
#   width: 10em;
#   background

# %%
styled_df[['drug', 'mimic_0', 'mimic_2', 'mimic_1', 'mimic_3', 'aumc_0','aumc_2', 'aumc_1','aumc_3']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fecb9c424c65> in <module>
# ----> 1 styled_df[['drug', 'mimic_0', 'mimic_2', 'mimic_1', 'mimic_3', 'aumc_0','aumc_2', 'aumc_1','aumc_3']]
#
# TypeError: 'Styler' object is not subscriptable
