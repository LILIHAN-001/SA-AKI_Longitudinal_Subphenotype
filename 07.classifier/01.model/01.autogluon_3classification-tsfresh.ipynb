# %%
# ref:
# https://github.com/cristian-data-science/machine_learning_projects/blob/c902e5720349fc1d2e3d5a3298daafe8693033a0/cv_load_autogluon.ipynb
# https://blog.csdn.net/wish_to_top/article/details/118031463

# %%
import pickle
import pandas as pd
from sklearn.metrics import classification_report

def my_save(List,filename,Global):
    # filename : name.pkl
    my_pickle = {}
    for key in List:
        try:
            my_pickle[key] = Global[key] #globals()[key]
        except TypeError:
            print('ERROR pickleing: {0}'.format(key))
    with open(filename, 'wb') as f:   # Python 3: open(..., 'wb')
        pickle.dump(my_pickle, f)


def my_load(filename,Global):
    with open(filename, 'rb') as f:  # Python 3: open(..., 'rb')
        my_shelf = pickle.load(f)

    for key in my_shelf:
        Global[key] = my_shelf[key]
# Out:
# /home/hanl/miniconda3/envs/sp_shock/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pandas as pd
import shap
import os
from collections import Counter
#os.environ['RAY_memory_monitor_refresh_ms'] = "0"
os.environ['RAY_memory_usage_threshold'] = "0.99"

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

#def plot_confusion_matrix(cm, savename, title='Confusion Matrix'):
def plot_confusion_matrix(cm, title='Confusion Matrix'):

    plt.figure(figsize=(6, 4), dpi=100)
    np.set_printoptions(precision=2)

    ind_array = np.arange(len(classes))
    x, y = np.meshgrid(ind_array, ind_array)
    for x_val, y_val in zip(x.flatten(), y.flatten()):
        c = cm[y_val][x_val]
        if c > 0.001:
            plt.text(x_val, y_val, "%0.2f" % (c,), color='black', va='center', ha='center')
    plt.imshow(cm, interpolation='nearest', cmap="YlGnBu") #viridis
    plt.title(title)
    plt.colorbar()
    xlocations = np.array(range(len(classes)))
    plt.xticks(xlocations, classes, rotation=90)
    plt.yticks(xlocations, classes)
    plt.ylabel('Actual label')
    plt.xlabel('Predict label')
    
    # offset the tick
    tick_marks = np.array(range(len(classes))) + 0.5
    plt.gca().set_xticks(tick_marks, minor=True)
    plt.gca().set_yticks(tick_marks, minor=True)
    plt.gca().xaxis.set_ticks_position('none')
    plt.gca().yaxis.set_ticks_position('none')
    plt.grid(True, which='minor', linestyle='-')
    plt.gcf().subplots_adjust(bottom=0.15)
#    plt.savefig(savename, format='png')
    plt.show()

# %%
def class_pred_calculate(df_stat):
    d_all = pd.DataFrame(df_stat.label.value_counts()).reset_index()
    d_all.columns = ["groupHPD","all_count"]
    d_true = pd.DataFrame(df_stat[df_stat["label"] == df_stat["pred"]].label.value_counts()).reset_index()
    d_true.columns = ["groupHPD","true_count"]
    d_true = pd.merge(d_true,d_all,how="inner",on="groupHPD")
    d_true["percent"] = round(d_true["true_count"] / d_true["all_count"]*100, 2)
    print(d_true,"\n")
    d_false = pd.DataFrame(df_stat[df_stat["label"] != df_stat["pred"]].label.value_counts()).reset_index()
    d_false.columns = ["groupHPD","false_count"]
    d_false = pd.merge(d_false,d_all,how="inner",on="groupHPD")
    d_false["percent"] = round(d_false["false_count"] / d_false["all_count"]*100, 2)
    print(d_false,"\n")
    d_false = d_false[["groupHPD","false_count"]]
    d_false.columns = ["label","false_count"]
    df_stat["count"] = 1
    d_false2 = df_stat[df_stat["label"] != df_stat["pred"]].groupby(["label","pred"]).agg({"count":"count"}).reset_index()
    d_false2 = pd.merge(d_false2,d_false,how="left",on="label")
    print(d_false2,"\n")
    return d_true, d_false, d_false2
# df_stat = pd.concat([y_train,y_pred],axis=1)
# df_stat.columns = ["label", "pred"]
# d_true, d_false, d_false2 = class_pred_calculate(df_stat)

# %%
def get_aucplot(one_model,X,y):
    from sklearn.preprocessing import label_binarize
    from sklearn.metrics import roc_curve, auc
    from scipy import interp
    n_classes = 3
    y_pred = predictor.predict(X, model=one_model)
    y_score = label_binarize(y_pred, classes=[1, 2,3])
    y_true = label_binarize(y, classes=[1, 2,3])
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    # Compute macro-average ROC curve and ROC area
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])
    # Finally average it and compute AUC
    mean_tpr /= n_classes
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    plt.plot(all_fpr, mean_tpr,linewidth=3, label='%s (AUC = %0.2f)' % (one_model, roc_auc["macro"])) # Macro
    plt.legend(loc='lower right')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    return fpr, roc_auc

# %%
save_path = './Result-a1234_tsfresh_MimiceICU_AUMC_CorrMICfilt/'  # raw_dataset

import os
make_path = save_path + "/input/"
make_path1 = save_path + "/result/"
print(make_path)
if not os.path.exists(make_path):
    os.makedirs(make_path)
if not os.path.exists(make_path1):
    os.makedirs(make_path1)
    
df = pd.read_csv("../00.data_generate/df_saki_tsfresh_generate_features_a1234_CorrMICfilt.csv")
print(df.shape)

datasplit_type = "train2_test1" # "train2_test1", "train1_test2"
choose_dataset = "aumcdb"  #['eicu','aumcdb', 'mimic']
train_sample_ = 0.7
# Out:
# ./Result-a1234_tsfresh_MimiceICU_AUMC_CorrMICfilt//input/
# (8644, 118)

# %% [markdown]
# # Split the dataset by dataset
# - One database is the training set and two databases are the test sets
# - Two databases are the training set and one database is the test set

# %%
def split_traintest(datasplit_type, choose_dataset):
    if datasplit_type == "train1_test2":
        train_dataset = choose_dataset #"mimic"
        dataset_lst = df.dataset.unique().tolist()
        dataset_lst.remove(train_dataset)
        test_dataset1 = dataset_lst[0]
        test_dataset2 = dataset_lst[1]

        train_set = df[df["dataset"]==train_dataset]
        test_set1 = df[df["dataset"]==test_dataset1]
        test_set2 = df[df["dataset"]==test_dataset2]
        
        train_set = train_set.drop(["dataset"],axis=1)
        test_set1 = test_set1.drop(["dataset"],axis=1)
        test_set2 = test_set2.drop(["dataset"],axis=1)
        data_path = save_path + './input/'
        infile = data_path + "train_set.csv"
        train_set.to_csv(infile,index=False)
        infile = data_path + "test_set1.csv"
        test_set1.to_csv(infile,index=False)
        infile = data_path + "test_set2.csv"
        test_set2.to_csv(infile,index=False)
        
        d1 = train_dataset
        d1_len = len(train_set.stay_id.unique())
        d2 = test_dataset1
        d2_len = len(test_set1.stay_id.unique())
        d3 = test_dataset2
        d3_len = len(test_set2.stay_id.unique())

    if datasplit_type == "train2_test1":
        import random
        SEED =100
        random.seed(SEED)
        train_sample = train_sample_
        
        test_dataset1 = choose_dataset #"eicu"
        dataset_lst = df.dataset.unique().tolist()
        dataset_lst.remove(test_dataset1)

        train_set = df[df["dataset"]!=test_dataset1]
        test_set = df[df["dataset"]==test_dataset1]
        
        unique_ids = train_set[train_set["dataset"]==dataset_lst[0]]['stay_id'].unique().tolist()
        random.shuffle(unique_ids)
        train_ids = unique_ids[:int(len(unique_ids) * train_sample)]
        val_ids = unique_ids[int(len(unique_ids) * train_sample):]

        unique_ids = train_set[train_set["dataset"]==dataset_lst[1]]['stay_id'].unique().tolist()
        random.shuffle(unique_ids)
        train_ids.extend(unique_ids[:int(len(unique_ids) * train_sample)])
        val_ids.extend(unique_ids[int(len(unique_ids) * train_sample):])
        
        val_set = train_set[train_set['stay_id'].isin(val_ids)]
        train_set = train_set[train_set['stay_id'].isin(train_ids)]

        train_set = train_set.drop(["dataset"],axis=1)
        val_set = val_set.drop(["dataset"],axis=1)
        test_set = test_set.drop(["dataset"],axis=1)
        
        data_path = save_path + './input/'
        infile = data_path + "train_set.csv"
        train_set.to_csv(infile,index=False)
        infile = data_path + "test_set1.csv"
        val_set.to_csv(infile,index=False)
        infile = data_path + "test_set2.csv"
        test_set.to_csv(infile,index=False)
        d1 = dataset_lst
        d1_len = len(train_set.stay_id.unique())
        d2 = dataset_lst
        d2_len = len(val_set.stay_id.unique())
        d3 = test_dataset1
        d3_len = len(test_set.stay_id.unique())
    return d1, d1_len, d2, d2_len, d3, d3_len 

d1_, d1_len_, d2_, d2_len_, d3_, d3_len_ = split_traintest(datasplit_type = datasplit_type, choose_dataset = choose_dataset)
print("training set:",d1_, str(d1_len_),"; test 1:",d2_, str(d2_len_),"; test 2:",d3_, str(d3_len_))

# %% [markdown]
# # Training

# %% [markdown]
# ## import data

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor
label = 'groupHPD'#
metric = "roc_auc_ovo_macro" #'accuracy',"f1_macro"
train_set = pd.read_csv(save_path + "/input/train_set.csv")
train_set = train_set.drop(columns=["stay_id"])

X_train = train_set.drop(columns=[label]) 
y_train = train_set[label]

# %% [markdown]
# ### SMOTE

# %%
# print(y_train.value_counts())
# from imblearn.over_sampling import SMOTE
# sampling_strategy = {1: y_train.value_counts()[1]*2, 2: y_train.value_counts()[2], 3: y_train.value_counts()[3]*8}

# sm = SMOTE(random_state=42) #,sampling_strategy=sampling_strategy
# X_train, y_train = sm.fit_resample(X_train, y_train)
# print(Counter(y_train))
# train_set = pd.concat([X_train,y_train],axis=1)

# %% [markdown]
# ### KMeans SMOTE

# %%
# print(y_train.value_counts())
# from imblearn.over_sampling import KMeansSMOTE
# sampling_strategy = {1: y_train.value_counts()[1]*2, 2: y_train.value_counts()[2], 3: y_train.value_counts()[3]*6}
# smo3 = KMeansSMOTE(k_neighbors=2,random_state=42,cluster_balance_threshold=0.1)#,sampling_strategy=sampling_strategy
# X_train, y_train = smo3.fit_resample(X_train, y_train)
# print(Counter(y_train))
# train_set = pd.concat([X_train,y_train],axis=1)

# %% [markdown]
# ### BorderlineSMOTE

# %%
# print(y_train.value_counts())
# from imblearn.over_sampling import BorderlineSMOTE
# smo2 = BorderlineSMOTE()
# X_train, y_train = smo2.fit_resample(X_train, y_train)
# print(y_train.value_counts())
# train_set = pd.concat([X_train,y_train],axis=1)

# %% [markdown]
# ### RandomUnderSampler

# %%
# from imblearn.under_sampling import RandomUnderSampler
# rus = RandomUnderSampler(sampling_strategy = {2: 1338}, random_state=0)
# X_train, y_train = rus.fit_resample(X_train, y_train)
# print(Counter(y_train))
# train_set = pd.concat([X_train,y_train],axis=1)

# %% [markdown]
# ## train

# %%
#"num_bag_sets" controls how many times the k-fold bagging process is repeated to further reduce variance (increasing this may further boost accuracy but will substantially increase training times, inference latency, and memory/disk usage)
#often see performance improve if you specify num_bag_folds = 5-10, num_stack_levels = 1-3 

predictor = TabularPredictor(label=label, path=save_path,problem_type="multiclass", 
                             eval_metric=metric).fit(train_set, 
                                                     presets='best_quality',
                                                     auto_stack=True,use_bag_holdout=True,
#                                                     num_bag_folds=3, num_bag_sets=5, num_stack_levels=1,
                                                     fit_weighted_ensemble=False, 
                                                     excluded_model_types=['KNN']
                                                                                                           )#time_limit=time_limit,

print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./Result-a1234_tsfresh_MimiceICU_AUMC_CorrMICfilt/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "./Result-a1234_tsfresh_MimiceICU_AUMC_CorrMICfilt/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.5
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Jul 6 19:56:57 EDT 2017
# Train Data Rows:    4522
# Train Data Columns: 115
# Label Column: groupHPD
# Preprocessing data ...
# Train Data Class Count: 3
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    152640.45 MB
# 	Train Data (Original)  Memory Usage: 4.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 49 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 115 | ['crea_divide_basecrea__abs_energy', 'crea_divide_basecrea__root_mean_square', 'crea_divide_basecrea__c3__lag_1', 'creatinine__linear_trend__attr_"intercept"', 'crea_divide_basecrea__sum_of_reoccurring_data_points', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 66 | ['crea_divide_basecrea__abs_energy', 'crea_divide_basecrea__root_mean_square', 'crea_divide_basecrea__c3__lag_1', 'creatinine__linear_trend__attr_"intercept"', 'crea_divide_basecrea__sum_of_reoccurring_data_points', ...]
# 		('int', ['bool']) : 49 | ['creatinine__fft_coefficient__attr_"angle"__coeff_2', 'creatinine__symmetry_looking__r_0.25', 'crea_divide_basecrea__number_cwt_peaks__n_1', 'bicarbonate__permutation_entropy__dimension_3__tau_1', 'urineoutput__has_duplicate', ...]
# 	0.2s = Fit runtime
# 	115 features in original data used to generate 115 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.61 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc_ovo_macro'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# Automatically generating train/validation split with holdout_frac=0.11057054400707651, Train Rows: 4022, Val Rows: 500
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded Model Types: ['KNN']
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting 11 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8455	 = Validation score   (roc_auc_ovo_macro)
# 	6.37s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8499	 = Validation score   (roc_auc_ovo_macro)
# 	8.13s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8527	 = Validation score   (roc_auc_ovo_macro)
# 	10.49s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ...
# 	0.8357	 = Validation score   (roc_auc_ovo_macro)
# 	0.69s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ...
# 	0.8405	 = Validation score   (roc_auc_ovo_macro)
# 	0.64s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8504	 = Validation score   (roc_auc_ovo_macro)
# 	16.85s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ...
# 	0.8289	 = Validation score   (roc_auc_ovo_macro)
# 	0.55s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ...
# 	0.8249	 = Validation score   (roc_auc_ovo_macro)
# 	0.54s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8472	 = Validation score   (roc_auc_ovo_macro)
# 	13.83s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8563	 = Validation score   (roc_auc_ovo_macro)
# 	7.03s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8446	 = Validation score   (roc_auc_ovo_macro)
# 	30.23s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Excluded Model Types: ['KNN']
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting 11 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8608	 = Validation score   (roc_auc_ovo_macro)
# 	5.21s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8551	 = Validation score   (roc_auc_ovo_macro)
# 	8.92s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8603	 = Validation score   (roc_auc_ovo_macro)
# 	11.16s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ...
# 	0.8548	 = Validation score   (roc_auc_ovo_macro)
# 	0.7s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ...
# 	0.8506	 = Validation score   (roc_auc_ovo_macro)
# 	0.83s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8616	 = Validation score   (roc_auc_ovo_macro)
# 	14.89s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ...
# 	0.8522	 = Validation score   (roc_auc_ovo_macro)
# 	0.69s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ...
# 	0.8505	 = Validation score   (roc_auc_ovo_macro)
# 	0.56s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8594	 = Validation score   (roc_auc_ovo_macro)
# 	12.75s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8628	 = Validation score   (roc_auc_ovo_macro)
# 	5.8s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.8533	 = Validation score   (roc_auc_ovo_macro)
# 	27.56s	 = Training   runtime
# 	0.22s	 = Validation runtime
# AutoGluon training complete, total runtime = 232.75s ... Best model: "NeuralNetTorch_BAG_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./Result-a1234_tsfresh_MimiceICU_AUMC_CorrMICfilt/")
# AutoGluon infers problem type is:  multiclass
# AutoGluon identified the following types of features:
# ('float', [])     : 66 | ['crea_divide_basecrea__abs_energy', 'crea_divide_basecrea__root_mean_square', 'crea_divide_basecrea__c3__lag_1', 'creatinine__linear_trend__attr_"intercept"', 'crea_divide_basecrea__sum_of_reoccurring_data_points', ...]
# ('int', ['bool']) : 49 | ['creatinine__fft_coefficient__attr_"angle"__coeff_2', 'creatinine__symmetry_looking__r_0.25', 'crea_divide_basecrea__number_cwt_peaks__n_1', 'bicarbonate__permutation_entropy__dimension_3__tau_1', 'urineoutput__has_duplicate', ...]

# %%
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
res = predictor.leaderboard(train_set, silent=True,extra_metrics=['accuracy','f1_weighted','precision_weighted','recall_weighted'])
outname = "result_train_" + str(d1_) +".csv"

res = res.sort_values(["score_val"],ascending=False)
res.to_csv(save_path + "/result/result_train_" + str(d1_) +".csv")
res.iloc[:10,:7]

# %%
best_model = np.array(res.iloc[:1,:1])[0].tolist()
y_pred = predictor.predict(X_train,model=best_model)
y_true = y_train

classes = [1,2,3]
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(cm_normalized, title='Confusion matrix')

# %% [markdown]
# # test set performance

# %% [markdown]
# ## test 1

# %%
test_set1 = pd.read_csv(save_path + "./input/test_set1.csv")
test_set1 = test_set1.drop(columns=["stay_id"])
print(d2_, "samples:",test_set1.shape[0])
y_test = test_set1[label]
X_test = test_set1.drop(columns=[label]) 

predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
print("best model:", predictor.get_model_best())

# %%
print("test set",d2_,"samples",test_set1.shape[0])
res = predictor.leaderboard(test_set1, silent=True,extra_metrics=['accuracy','balanced_accuracy',"precision_macro","precision_micro","precision_weighted","recall_macro","recall_micro","recall_weighted", 
'f1_weighted',"f1_macro","f1_micro"])
res = res.iloc[:,:14]

model_lst = res.model.unique().tolist()
y_true = y_test
res_eachlabel = pd.DataFrame()
for one_model in model_lst:
    y_pred = predictor.predict(X_test,model=one_model)
    t = classification_report(y_true, y_pred, target_names=["1","2","3"],output_dict=True)
    df_t = pd.DataFrame.from_dict(t)
    df_t = df_t.drop(["macro avg","weighted avg", 'accuracy'],axis=1)
    df_t.columns = ['C1', 'C2', 'C3'] #, 'macro', 'weighted'
    new_columns = [row + '_' + col for row in df_t.index for col in df_t.columns ]
    df_t = pd.DataFrame(df_t.values.flatten()).T
    df_t.columns = new_columns
    res_eachlabel = pd.concat([res_eachlabel, df_t],axis=0)
res_eachlabel['model'] = model_lst
res_eachlabel = res_eachlabel.filter(regex=r'^(?!support)')

# merge out
res_ = pd.merge(res,res_eachlabel,how="inner",on="model")
res_ = res_.rename(columns={"score_val":"AUC_val","score_test":"AUC_test","f1-score_C1":"f1_C1","f1-score_C2":"f1_C2","f1-score_C3":"f1_C3"})

outname = "result_test_" + str(d2_) +".csv"
print("output:",outname)
res_.to_csv(save_path + "/result/result_test_" + str(d2_) +".csv")
res_.head(2)

# %%
best_model = [predictor.get_model_best()]  

print(str(d2_)+":\n",str(best_model[0]))
y_true = y_test
y_pred = predictor.predict(X_test,model=best_model)

classes = [1,2,3]
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# plot
plt.figure(figsize=(6,4)) 
plot_confusion_matrix(cm_normalized, title='Confusion matrix')
tit = save_path + "/result/confusion_matrix_test1.pdf"
plt.savefig(tit, format='pdf')
plt.close()
plt.show()
# Out:
# ['eicu', 'mimic']:
#  NeuralNetTorch_BAG_L2

# %%
plt.figure(figsize=(10,7))
model_lst = res.model.unique().tolist()
for one_model in model_lst: # [0:3]
    print(one_model)
    fpr, roc_auc = get_aucplot(one_model,X_test,y_test)
# Out:
# NeuralNetFastAI_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetTorch_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# CatBoost_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesEntr_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMXT_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# XGBoost_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestEntr_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBM_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMXT_BAG_L1
# CatBoost_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesGini_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBM_BAG_L1
# RandomForestGini_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetTorch_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# XGBoost_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMLarge_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMLarge_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetFastAI_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestEntr_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestGini_BAG_L1
# ExtraTreesGini_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesEntr_BAG_L1

# %%
# y_pred_proba  = predictor.predict_proba(X_test, as_pandas=True,model=best_model)
# perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred_proba, auxiliary_metrics=True) #,y_pred_proba=y_pred_proba
# print(perf)

# %% [markdown]
# ## test 2

# %%
test_set2 = pd.read_csv(save_path + "./input/test_set2.csv")
test_set2 = test_set2.drop(columns=["stay_id"])

print(d3_, "samples",test_set2.shape[0])
y_test = test_set2[label]
X_test = test_set2.drop(columns=[label]) 

predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
print("best models:", predictor.get_model_best())

# %%
print("test set:",d3_,"samples:",test_set2.shape[0])
res = predictor.leaderboard(test_set2, silent=True,extra_metrics=['accuracy','balanced_accuracy',"precision_macro","precision_micro","precision_weighted","recall_macro","recall_micro","recall_weighted", 
'f1_weighted',"f1_macro","f1_micro"])
res = res.iloc[:,:14]

model_lst = res.model.unique().tolist()
y_true = y_test
res_eachlabel = pd.DataFrame()
for one_model in model_lst:
    y_pred = predictor.predict(X_test,model=one_model)
    t = classification_report(y_true, y_pred, target_names=["1","2","3"],output_dict=True)
    df_t = pd.DataFrame.from_dict(t)
    df_t = df_t.drop(["macro avg","weighted avg", 'accuracy'],axis=1)
    df_t.columns = ['C1', 'C2', 'C3'] #, 'macro', 'weighted'
    new_columns = [row + '_' + col for row in df_t.index for col in df_t.columns ]
    df_t = pd.DataFrame(df_t.values.flatten()).T
    df_t.columns = new_columns
    res_eachlabel = pd.concat([res_eachlabel, df_t],axis=0)
res_eachlabel['model'] = model_lst
res_eachlabel = res_eachlabel.filter(regex=r'^(?!support)')

# merge out
res_ = pd.merge(res,res_eachlabel,how="inner",on="model")
res_ = res_.rename(columns={"score_val":"AUC_val","score_test":"AUC_test","f1-score_C1":"f1_C1","f1-score_C2":"f1_C2","f1-score_C3":"f1_C3"})

outname = "result_test_" + str(d3_) +".csv"
print("output:",outname)
res_.to_csv(save_path + "/result/result_test_" + str(d3_) +".csv")
res_.head(2)

# %%
best_model = [predictor.get_model_best()]  

print(str(d3_)+":\n",str(best_model[0]))
y_true = y_test
y_pred = predictor.predict(X_test,model=best_model)

classes = [1,2,3]
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# plot
plot_confusion_matrix(cm_normalized, title='Confusion matrix')
tit = save_path + "/result/confusion_matrix_test2.png"
plt.savefig(tit, format='png')
plt.show()
# Out:
# aumcdb:
#  NeuralNetTorch_BAG_L2

# %%
plt.figure(figsize=(10,7))
model_lst = res.model.unique().tolist()
for one_model in model_lst: # [0:3]
    print(one_model)
    fpr, roc_auc = get_aucplot(one_model,X_test,y_test)
# Out:
# LightGBMXT_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBM_BAG_L1
# XGBoost_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestEntr_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# CatBoost_BAG_L1
# LightGBMXT_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# CatBoost_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMLarge_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesGini_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesEntr_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBM_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestGini_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# XGBoost_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesEntr_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestEntr_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ExtraTreesGini_BAG_L1
# NeuralNetTorch_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# LightGBMLarge_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# RandomForestGini_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetFastAI_BAG_L2
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetTorch_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# NeuralNetFastAI_BAG_L1
# scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# y_pred_proba  = predictor.predict_proba(X_test, as_pandas=True)# ,model=["CatBoost_BAG_L1","ExtraTreesEntr_BAG_L1","WeightedEnsemble_L2"])
# perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred_proba, auxiliary_metrics=True) #,y_pred_proba=y_pred_proba
# print(perf)

# %% [markdown]
# # Feature importance
# https://github.com/autogluon/autogluon/blob/master/examples/tabular/interpret/SHAP%20with%20AutoGluon-Tabular.ipynb

# %%
test_set1 = pd.read_csv(save_path + "./input/test_set1.csv")
test_set1 = test_set1.drop(columns=["stay_id"])
print(d2_, "samples:",test_set1.shape[0])

label_counts = test_set1[label].value_counts()
sampled_df = pd.DataFrame()
for label_value, count in label_counts.items():
#    sampled_df = sampled_df.append(test_set1[test_set1[label] == label_value].sample(n=label_counts[3], replace=False))
    sampled_df = sampled_df.append(test_set1[test_set1[label] == label_value].sample(n=label_counts[3], replace=False))
test_set1 = sampled_df
print(d2_, "Sample size after sampling:",test_set1.shape[0])

y_test = test_set1[label]
X_test = test_set1.drop(columns=[label])

# %%
predictor_multi = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
#model_fi = predictor_multi.feature_importance(train_set) # ,model=

# %%
class AutogluonWrapper:
    def __init__(self, predictor, feature_names, target_class=None):
        self.ag_model = predictor
        self.feature_names = feature_names
        self.target_class = target_class
        if target_class is None and predictor.problem_type != 'regression':
            print("Since target_class not specified, SHAP will explain predictions for each class")
    
    def predict_proba(self, X):
        if isinstance(X, pd.Series):
            X = X.values.reshape(1,-1)
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X, columns=self.feature_names)
        preds = self.ag_model.predict_proba(X)
        if predictor.problem_type == "regression" or self.target_class is None:
            return preds
        else:
            return preds[self.target_class]

# %%
baseline = X_train.sample(1000, random_state=30)

ag_wrapper = AutogluonWrapper(predictor_multi, X_train.columns)
explainer = shap.KernelExplainer(ag_wrapper.predict_proba, baseline)
print("Baseline prediction: \n", ag_wrapper.predict_proba(baseline).mean())  # this is the same as explainer.expected_value

NSHAP_SAMPLES = 100  # how many samples to use to approximate each Shapely value, larger values will be slower
# Out:
# Since target_class not specified, SHAP will explain predictions for each class
# Using 1000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# Baseline prediction:
#  1.0    0.292447
# 2.0    0.613020
# 3.0    0.094533
# dtype: float32

# %%
shap_values = explainer.shap_values(X_test, nsamples=NSHAP_SAMPLES,model=best_model)
filename = save_path + r'/result/shap_related.pkl'
save_lst = ["shap_values"]
my_save(save_lst, filename, globals())
# Out:
#   0%|          | 0/495 [00:00<?, ?it/s]
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.325e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 118 iterations, alpha=4.390e-05, previous alpha=4.000e-05, with an active set of 41 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.017e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 98 iterations, alpha=1.916e-04, previous alpha=1.916e-04, with an active set of 39 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=7.107e-05, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 45 iterations, alpha=2.595e-05, previous alpha=2.307e-05, with an active set of 36 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 88 iterations, alpha=4.907e-07, previous alpha=4.789e-07, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=4.018e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=4.018e-07, previous alpha=3.997e-07, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=3.960e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 108 iterations, alpha=9.385e-06, previous alpha=9.385e-06, with an active set of 47 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=3.351e-05, with an active set of 34 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 130 iterations, alpha=5.040e-06, previous alpha=5.040e-06, with an active set of 47 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 86 iterations, alpha=8.778e-06, previous alpha=8.778e-06, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=3.529e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.098e-05, with an active set of 44 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=5.638e-06, previous alpha=5.638e-06, with an active set of 48 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.626e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 124 iterations, i.e. alpha=1.198e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 168 iterations, alpha=9.982e-04, previous alpha=9.982e-04, with an active set of 43 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.027e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 135 iterations, alpha=4.825e-04, previous alpha=4.825e-04, with an active set of 42 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 105 iterations, alpha=2.435e-07, previous alpha=2.435e-07, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=4.302e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=4.230e-06, with an active set of 50 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 71 iterations, alpha=2.116e-06, previous alpha=2.116e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.985e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=3.551e-04, with an active set of 41 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 171 iterations, alpha=3.562e-04, previous alpha=3.547e-04, with an active set of 58 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=6.081e-03, with an active set of 18 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 180 iterations, alpha=1.004e-03, previous alpha=1.003e-03, with an active set of 73 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=1.972e-04, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 231 iterations, alpha=3.671e-05, previous alpha=3.668e-05, with an active set of 80 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=1.893e-04, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=1.760e-04, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=1.626e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.365e-04, with an active set of 26 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.362e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.357e-04, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.211e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=7.851e-05, previous alpha=7.486e-05, with an active set of 36 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=9.034e-05, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.981e-05, with an active set of 36 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 47 iterations, i.e. alpha=4.885e-05, with an active set of 37 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=4.633e-05, with an active set of 40 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=3.912e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 55 iterations, alpha=3.428e-05, previous alpha=3.281e-05, with an active set of 44 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.610e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=7.670e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=7.670e-04, previous alpha=7.632e-04, with an active set of 29 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=1.130e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 152 iterations, alpha=1.673e-04, previous alpha=1.673e-04, with an active set of 39 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.061e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 120 iterations, alpha=1.399e-03, previous alpha=1.375e-03, with an active set of 37 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.227e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 118 iterations, alpha=4.130e-03, previous alpha=4.122e-03, with an active set of 35 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.004e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=2.771e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 63 iterations, i.e. alpha=1.431e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.260e-03, with an active set of 21 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 185 iterations, alpha=8.148e-04, previous alpha=8.148e-04, with an active set of 36 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=2.333e-05, with an active set of 39 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=2.262e-05, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 77 iterations, alpha=9.552e-06, previous alpha=8.985e-06, with an active set of 42 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 83 iterations, i.e. alpha=1.552e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 84 iterations, i.e. alpha=1.457e-06, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 85 iterations, alpha=1.457e-06, previous alpha=1.397e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=7.334e-04, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 87 iterations, alpha=2.038e-04, previous alpha=2.037e-04, with an active set of 34 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.131e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 159 iterations, alpha=2.588e-04, previous alpha=2.570e-04, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.286e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 104 iterations, alpha=1.977e-03, previous alpha=1.945e-03, with an active set of 37 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.876e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=1.876e-06, previous alpha=1.829e-06, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.490e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 150 iterations, alpha=6.639e-04, previous alpha=6.622e-04, with an active set of 41 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.521e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 165 iterations, alpha=3.600e-03, previous alpha=3.600e-03, with an active set of 42 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=2.687e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 175 iterations, alpha=4.386e-04, previous alpha=4.386e-04, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=9.077e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 82 iterations, alpha=4.539e-06, previous alpha=4.539e-06, with an active set of 49 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 105 iterations, alpha=1.026e-06, previous alpha=1.026e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=8.028e-05, with an active set of 40 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=2.059e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 82 iterations, alpha=1.772e-05, previous alpha=1.772e-05, with an active set of 47 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=2.311e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=2.753e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=2.696e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 109 iterations, alpha=2.570e-04, previous alpha=2.407e-04, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.037e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.410e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=4.409e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 55 iterations, alpha=2.716e-03, previous alpha=2.713e-03, with an active set of 26 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 91 iterations, alpha=1.496e-05, previous alpha=1.456e-05, with an active set of 48 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.426e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=6.366e-04, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=2.227e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 115 iterations, alpha=2.224e-04, previous alpha=2.156e-04, with an active set of 34 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=1.787e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 85 iterations, alpha=8.388e-06, previous alpha=8.388e-06, with an active set of 48 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=2.667e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 119 iterations, alpha=5.609e-04, previous alpha=5.364e-04, with an active set of 36 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.161e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 120 iterations, alpha=2.880e-04, previous alpha=2.867e-04, with an active set of 35 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 105 iterations, alpha=1.081e-06, previous alpha=1.081e-06, with an active set of 50 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 81 iterations, alpha=1.266e-06, previous alpha=1.266e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.914e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=3.914e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.957e-03, with an active set of 33 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=1.736e-03, previous alpha=1.724e-03, with an active set of 32 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.292e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 55 iterations, alpha=1.241e-04, previous alpha=1.210e-04, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=1.537e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 74 iterations, alpha=1.537e-06, previous alpha=1.524e-06, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=1.512e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 108 iterations, alpha=7.559e-06, previous alpha=7.559e-06, with an active set of 47 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.884e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=5.161e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=5.136e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=5.132e-05, previous alpha=5.039e-05, with an active set of 42 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=2.466e-07, previous alpha=2.466e-07, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=1.111e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 89 iterations, alpha=5.530e-06, previous alpha=5.530e-06, with an active set of 46 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=7.546e-07, with an active set of 50 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=7.462e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 72 iterations, alpha=7.462e-07, previous alpha=7.038e-07, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=1.181e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 48 iterations, i.e. alpha=5.907e-05, with an active set of 34 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=4.960e-05, previous alpha=4.954e-05, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=2.029e-06, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=2.023e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 57 iterations, alpha=2.021e-06, previous alpha=2.019e-06, with an active set of 44 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.110e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 187 iterations, alpha=3.432e-04, previous alpha=3.432e-04, with an active set of 32 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=2.138e-02, with an active set of 10 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 126 iterations, alpha=7.516e-03, previous alpha=7.066e-03, with an active set of 43 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.821e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 121 iterations, alpha=1.364e-04, previous alpha=1.364e-04, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.875e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 133 iterations, alpha=4.995e-03, previous alpha=4.873e-03, with an active set of 42 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.518e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 122 iterations, alpha=4.248e-03, previous alpha=4.221e-03, with an active set of 39 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=9.049e-05, with an active set of 40 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=2.088e-05, previous alpha=2.043e-05, with an active set of 43 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=6.914e-03, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=7.305e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=7.144e-04, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 59 iterations, alpha=7.206e-04, previous alpha=7.140e-04, with an active set of 34 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=9.258e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 83 iterations, alpha=2.355e-03, previous alpha=2.355e-03, with an active set of 34 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=7.995e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 170 iterations, alpha=6.966e-07, previous alpha=6.966e-07, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=5.300e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.859e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 17 iterations, alpha=1.426e-03, previous alpha=1.373e-03, with an active set of 16 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.541e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 65 iterations, alpha=2.882e-03, previous alpha=2.882e-03, with an active set of 32 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=1.337e-05, with an active set of 40 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 114 iterations, alpha=4.137e-06, previous alpha=4.137e-06, with an active set of 51 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 97 iterations, alpha=3.825e-05, previous alpha=3.746e-05, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.539e-04, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 83 iterations, i.e. alpha=4.639e-05, with an active set of 35 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 118 iterations, alpha=3.522e-05, previous alpha=3.485e-05, with an active set of 39 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=5.668e-06, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=4.277e-06, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 81 iterations, alpha=1.791e-06, previous alpha=1.705e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=9.889e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 134 iterations, alpha=2.457e-03, previous alpha=2.457e-03, with an active set of 35 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=5.448e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 95 iterations, alpha=1.129e-03, previous alpha=1.129e-03, with an active set of 28 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.284e-02, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 125 iterations, alpha=2.137e-03, previous alpha=2.137e-03, with an active set of 40 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=2.342e-06, previous alpha=2.342e-06, with an active set of 44 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=4.209e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 76 iterations, alpha=1.504e-04, previous alpha=1.503e-04, with an active set of 35 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=1.158e-02, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 143 iterations, alpha=1.860e-03, previous alpha=1.860e-03, with an active set of 42 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=4.365e-05, with an active set of 29 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 60 iterations, i.e. alpha=7.250e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=6.898e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=7.109e-06, previous alpha=6.717e-06, with an active set of 46 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=3.253e-06, previous alpha=3.253e-06, with an active set of 50 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.130e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=3.865e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 57 iterations, alpha=1.261e-04, previous alpha=1.247e-04, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.812e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 113 iterations, alpha=1.001e-03, previous alpha=1.001e-03, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=3.119e-04, with an active set of 27 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.718e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=1.259e-04, previous alpha=1.254e-04, with an active set of 36 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=2.553e-06, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=1.089e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 87 iterations, alpha=8.647e-07, previous alpha=8.647e-07, with an active set of 48 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=3.323e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 129 iterations, alpha=5.501e-04, previous alpha=5.501e-04, with an active set of 44 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=1.538e-02, with an active set of 19 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 147 iterations, alpha=2.667e-03, previous alpha=2.644e-03, with an active set of 44 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 112 iterations, i.e. alpha=1.157e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=1.157e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 138 iterations, i.e. alpha=7.831e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=5.784e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 146 iterations, alpha=5.784e-05, previous alpha=5.784e-05, with an active set of 43 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 123 iterations, i.e. alpha=6.326e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 124 iterations, i.e. alpha=6.206e-06, with an active set of 46 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 128 iterations, alpha=4.937e-06, previous alpha=4.855e-06, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.519e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=4.769e-04, with an active set of 19 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 22 iterations, alpha=4.680e-04, previous alpha=4.574e-04, with an active set of 19 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 83 iterations, alpha=1.423e-05, previous alpha=1.302e-05, with an active set of 46 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 50 iterations, alpha=1.377e-04, previous alpha=1.359e-04, with an active set of 31 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 10 iterations, i.e. alpha=1.517e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 95 iterations, alpha=2.737e-04, previous alpha=2.737e-04, with an active set of 38 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=3.721e-05, with an active set of 39 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=1.421e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 78 iterations, i.e. alpha=8.379e-06, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 78 iterations, i.e. alpha=7.947e-06, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=7.565e-06, previous alpha=6.924e-06, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=6.884e-05, with an active set of 33 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=3.388e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 57 iterations, alpha=3.378e-05, previous alpha=3.298e-05, with an active set of 42 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.349e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=5.674e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=3.351e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 28 iterations, alpha=1.685e-03, previous alpha=1.657e-03, with an active set of 21 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.612e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 122 iterations, alpha=3.985e-03, previous alpha=3.985e-03, with an active set of 39 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.764e-02, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.989e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 101 iterations, alpha=1.194e-02, previous alpha=1.194e-02, with an active set of 46 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 96 iterations, alpha=6.853e-06, previous alpha=6.767e-06, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=7.498e-04, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 124 iterations, alpha=1.638e-04, previous alpha=1.638e-04, with an active set of 33 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.652e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 145 iterations, alpha=4.541e-03, previous alpha=4.537e-03, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=8.882e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 125 iterations, alpha=1.294e-03, previous alpha=1.294e-03, with an active set of 44 regressors.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 84 iterations, alpha=2.992e-06, previous alpha=2.992e-06, with an active set of 51 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.214e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 65 iterations, alpha=3.006e-03, previous alpha=3.006e-03, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=2.962e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 77 iterations, alpha=1.291e-05, previous alpha=1.291e-05, with an active set of 46 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=2.344e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 60 iterations, i.e. alpha=2.329e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 61 iterations, alpha=2.299e-05, previous alpha=2.283e-05, with an active set of 48 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=1.442e-04, with an active set of 34 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 182 iterations, i.e. alpha=3.638e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 184 iterations, alpha=3.635e-05, previous alpha=3.631e-05, with an active set of 49 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.875e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 145 iterations, alpha=1.531e-04, previous alpha=1.520e-04, with an active set of 40 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=6.758e-03, with an active set of 4 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 78 iterations, i.e. alpha=1.192e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 79 iterations, alpha=1.191e-03, previous alpha=1.186e-03, with an active set of 34 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=5.259e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 160 iterations, alpha=7.245e-04, previous alpha=7.135e-04, with an active set of 43 regressors.
# Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=3.623e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 174 iterations, alpha=5.011e-04, previous alpha=5.011e-04, with an active set of 39 regressors.

# %% [markdown]
# ## Beeswarm diagram
# Each point is a sample (person), and the picture contains all the samples
# X-axis: Samples are sorted by Shap value -
# Y-axis: Features are sorted by Shap value
# Color: The larger the value of the feature, the redder it is

# %%
filename = save_path + r'/result/shap_related.pkl'
my_load(filename, globals())

# %%
shap.summary_plot(shap_values[0], X_test, show=False) #,save=True,path=pth,show=False
tit = save_path + "/result/shap_beeswarm_test_C1.pdf"
plt.savefig(tit, format='pdf')
plt.show()

# %%
shap.summary_plot(shap_values[1], X_test, show=False)
tit = save_path + "/result/shap_beeswarm_test_C2.pdf"
plt.savefig(tit, format='pdf')
plt.show()

# %%
shap.summary_plot(shap_values[2], X_test, show=False)
tit = save_path + "/result/shap_beeswarm_test_C3.pdf"
plt.savefig(tit, format='pdf')
plt.show()

# %% [markdown]
# ## bar 1

# %%
# shap.summary_plot(shap_values, X_test, show = False, max_display=10, plot_type="bar")#, feature_names = np.array(["C1","C2","C3"])) #
# plt.tight_layout()
# plt.show()
# print({"Class "+str(i) : predictor_multi.class_labels[i] for i in range(len(predictor_multi.class_labels))})

num_unit = 10
shap.summary_plot(shap_values, X_test, show = False, max_display=num_unit, plot_type="bar") 
colors = ["#91cf60","#91bfdb","#fc8d59"]
bars = plt.gca().patches

for i, bar in enumerate(bars):
    j = 0 
    if i >= num_unit:
        j = 1
    if i >= num_unit*2:
        j = 2
    bar.set_color(colors[j]) #colors[i % len(colors)]
    
labels = ['C2', 'C1', 'C3']  
handles = [plt.Rectangle((0,0),1,1, color=color) for color in colors]
plt.legend(handles, labels)
tit = save_path + "/result/shap_bar_test.pdf"
plt.savefig(tit, format='pdf')
plt.show()

# %% [markdown]
# ## bar 2

# %%
fig = plt.figure(figsize=(30,5))

ax0 = fig.add_subplot(131)
ax0.title.set_text('C1')
shap.summary_plot(shap_values[0], X_test, plot_type="bar", show=False, max_display=10)
bars = plt.gca().patches
for i, bar in enumerate(bars):
    bar.set_color(colors[1])
ax0.set_xlabel(r'SHAP values', fontsize=12)
plt.subplots_adjust(wspace = 2)

ax1 = fig.add_subplot(132)
ax1.title.set_text('C2')
shap.summary_plot(shap_values[1], X_test, plot_type="bar", show=False, max_display=10)
plt.subplots_adjust(left=0.001, right=0.99, bottom=0.1, top=0.9)
bars = plt.gca().patches
for i, bar in enumerate(bars):
    bar.set_color(colors[0])
ax1.set_xlabel(r'SHAP values', fontsize=12)

ax2 = fig.add_subplot(133)
ax2.title.set_text('C3')
shap.summary_plot(shap_values[2], X_test, plot_type="bar", show=False, max_display=10)
plt.subplots_adjust(left=0.00001, right=0.99, bottom=0.1, top=0.9)
bars = plt.gca().patches
for i, bar in enumerate(bars):
    bar.set_color(colors[2])
ax2.set_xlabel(r'SHAP values', fontsize=12)
plt.tight_layout(pad=10)  
tit = save_path + "/result/shap_bar2_test.pdf"
plt.savefig(tit, format='pdf')

plt.show()
# Out:
# Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
# ROW_INDEX = 0  # index of an example datapoint
# class_of_interest = 1  # can be any value in set(y_train)
# class_index = predictor_multi.class_labels.index(class_of_interest)

# single_datapoint = X_train.iloc[[ROW_INDEX]]
# single_prediction = ag_wrapper.predict_proba(single_datapoint)

# shap_values_single = explainer.shap_values(single_datapoint, nsamples=NSHAP_SAMPLES)
# print("Shapely values: \n", {predictor_multi.class_labels[i]:shap_values_single[i] for i in range(len(predictor_multi.class_labels))})

# print(f"Force_plot for class: {class_of_interest}")
# shap.force_plot(explainer.expected_value[class_index], shap_values_single[class_index], X_train.iloc[ROW_INDEX,:])

# %% [markdown]
# # some knowledge

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# https://docs.aws.amazon.com/zh_cn/sagemaker/latest/dg/autogluon-tabular-HowItWorks.html

# %% [markdown]
# ![image.png](attachment:image.png)
